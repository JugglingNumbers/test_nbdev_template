# %%
# default_exp core

# %% [markdown]
# # module name here
#
# > API details.

# %%
#hide
LIB_NAME = "test_nbdev_template"
path_to_repository = 'git'

import os
if os.listdir() == ['.config', 'sample_data']:
    IN_COLAB = True


if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    library_root = f'"drive/MyDrive/{path_to_repository}/{LIB_NAME}"'
    # %cd $library_root
    # !pip3 install -e . -q
    # !pip3 install nbdev -q
# Out:
# /content/drive/MyDrive/git/test_nbdev_template

# %%
#hide
from nbdev.showdoc import *

# %%
#|export
def say_hello(to):
    "Say hello to somebody"
    return f'Hello {to}!'

# %%
say_hello("Sylvain")
# Out:
# 'Hello Sylvain!'

# %%
#|export
def say_goodbye(to):
    "Say goodbye to somebody"
    return f'Goodbye {to}!'

# %%
say_goodbye("Sylvain")
# Out:
# 'Goodbye Sylvain!'

# %%
from IPython.display import display,SVG

# %%
display(SVG('<svg height="100"><circle cx="50" cy="50" r="40"/></svg>'))

# %%
assert say_hello("Jeremy")=="Hello Jeremy!"

# %%
#hide
if IN_COLAB:
    # !nbdev_build_lib
    # !nbdev_build_docs
# Out:
# Converted 00_core.ipynb.
# Converted index.ipynb.
# converting: /content/drive/MyDrive/git/test_nbdev_template/00_core.ipynb
# converting /content/drive/MyDrive/git/test_nbdev_template/index.ipynb to README.md

# %%
#hide
'''
# !git config user.name = "JugglingNumbers"
# !git config user.email = "{ID}+{username}@users.noreply.github.com"
# !git add *
# !git commit -m "Test commit message"
# !git push origin master
'''
# Out:
# error: invalid pattern: {ID}+{username}@users.noreply.github.com
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@8755ead49550.(none)')
# Everything up-to-date
