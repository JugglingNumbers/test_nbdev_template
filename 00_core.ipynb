# %%
# default_exp core

# %% [markdown]
# # Key pieces to have a colab compatible nbdev based github library
#
# > clone / copy this library https://github.com/JugglingNumbers/test_nbdev_template which is based on https://github.com/fastai/nbdev_template/
#
# >

# %%
#hide

LIB_NAME = "test_nbdev_template"
path_to_repository = 'git'

import os
if os.listdir() == ['.config', 'sample_data']:
    IN_COLAB = True


if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    library_root = f'"drive/MyDrive/{path_to_repository}/{LIB_NAME}"'
    # %cd $library_root
    # !pip3 install -e . -q
    # !pip3 install nbdev -q
# Out:
# /content/drive/MyDrive/git/test_nbdev_template

# %%
#hide
from nbdev.showdoc import *

# %%
#|export
def say_hello(to):
    "Say hello to somebody"
    return f'Hello {to}!'

# %%
say_hello("Sylvain")
# Out:
# 'Hello Sylvain!'

# %%
#|export
def say_goodbye(to):
    "Say goodbye to somebody"
    return f'Goodbye {to}!'

# %%
say_goodbye("Sylvain")
# Out:
# 'Goodbye Sylvain!'

# %%
from IPython.display import display,SVG

# %%
display(SVG('<svg height="100"><circle cx="50" cy="50" r="40"/></svg>'))

# %%
assert say_hello("Jeremy")=="Hello Jeremy!"

# %%
#hide
if IN_COLAB:
    # !nbdev_build_lib
    # !nbdev_build_docs
# Out:
# Converted 00_core.ipynb.
# Converted index.ipynb.
# converting: /content/drive/MyDrive/git/test_nbdev_template/00_core.ipynb
# converting /content/drive/MyDrive/git/test_nbdev_template/index.ipynb to README.md

# %%
#hide
'''
# !git config user.name = "JugglingNumbers"
# !git config user.email = "JugglingNumbers@users.noreply.github.com"
# !git add *
# !git commit -m "Test commit message"
# !git push origin master
'''
# Out:
# [master 67c00b2] Test commit message
#  23 files changed, 1 insertion(+), 1 deletion(-)
#  mode change 100755 => 100644 00_core.ipynb
#  mode change 100755 => 100644 CONTRIBUTING.md
#  mode change 100755 => 100644 LICENSE
#  mode change 100755 => 100644 MANIFEST.in
#  mode change 100755 => 100644 Makefile
#  mode change 100755 => 100644 README.md
#  mode change 100755 => 100644 docker-compose.yml
#  mode change 100755 => 100644 docs/.gitignore
#  mode change 100755 => 100644 docs/Gemfile
#  mode change 100755 => 100644 docs/_config.yml
#  mode change 100755 => 100644 docs/_data/sidebars/home_sidebar.yml
#  mode change 100755 => 100644 docs/_data/topnav.yml
#  mode change 100755 => 100644 docs/core.html
#  mode change 100755 => 100644 docs/feed.xml
#  mode change 100755 => 100644 docs/index.html
#  mode change 100755 => 100644 docs/sidebar.json
#  mode change 100755 => 100644 docs/sitemap.xml
#  mode change 100755 => 100644 index.ipynb
#  mode change 100755 => 100644 settings.ini
# ...
